# %%
import pandas as pd

# %%
df = pd.read_csv('global_cancer_patients_2015_2024.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Patient_ID             50000 non-null  object
#  1   Age                    50000 non-null  int64
#  2   Gender                 50000 non-null  object
#  3   Country_Region         50000 non-null  object
#  4   Year                   50000 non-null  int64
#  5   Genetic_Risk           50000 non-null  float64
#  6   Air_Pollution          50000 non-null  float64
#  7   Alcohol_Use            50000 non-null  float64
#  8   Smoking                50000 non-null  float64
#  9   Obesity_Level          50000 non-null  float64
#  10  Cancer_Type            50000 non-null  object
#  11  Cancer_Stage           50000 non-null  object
#  12  Treatment_Cost_USD     50000 non-null  float64
#  13  Survival_Years         50000 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 Age          Year  Genetic_Risk  Air_Pollution   Alcohol_Use  \
# count  50000.000000  50000.000000  50000.000000   50000.000000  50000.000000
# mean      54.421540   2019.480520      5.001698       5.010126      5.010880
# std       20.224451      2.871485      2.885773       2.888399      2.888769
# min       20.000000   2015.000000      0.000000       0.000000      0.000000
# 25%       37.000000   2017.000000      2.500000       2.500000      2.500000
# 50%       54.000000   2019.000000      5.000000       5.000000      5.000000
# 75%       72.000000   2022.000000      7.500000       7.500000      7.500000
# max       89.000000   2024.000000     10.000000      10.000000     10.000000
#
#             Smoking  Obesity_Level  Treatment_Cost_USD  Survival_Years  \
# count  50000.000000   50000.000000        50000.000000    50000.000000
# mean       4.989826       4.991176        52467.298239        5.006462
# ...

# %%
df.isnull().sum()
# Out:
# Patient_ID               0
# Age                      0
# Gender                   0
# Country_Region           0
# Year                     0
# Genetic_Risk             0
# Air_Pollution            0
# Alcohol_Use              0
# Smoking                  0
# Obesity_Level            0
# Cancer_Type              0
# Cancer_Stage             0
# Treatment_Cost_USD       0
# Survival_Years           0
# Target_Severity_Score    0
# dtype: int64

# %%
df.head()
# Out:
#   Patient_ID  Age  Gender Country_Region  Year  Genetic_Risk  Air_Pollution  \
# 0  PT0000000   71    Male             UK  2021           6.4            2.8
# 1  PT0000001   34    Male          China  2021           1.3            4.5
# 2  PT0000002   80    Male       Pakistan  2023           7.4            7.9
# 3  PT0000003   40    Male             UK  2015           1.7            2.9
# 4  PT0000004   43  Female         Brazil  2017           5.1            2.8
#
#    Alcohol_Use  Smoking  Obesity_Level Cancer_Type Cancer_Stage  \
# 0          9.5      0.9            8.7        Lung    Stage III
# 1          3.7      3.9            6.3    Leukemia      Stage 0
# 2          2.4      4.7            0.1      Breast     Stage II
# 3          4.8      3.5            2.7       Colon      Stage I
# 4          2.3      6.7            0.5        Skin    Stage III
#
#    Treatment_Cost_USD  Survival_Years  Target_Severity_Score
# 0            62913.44             5.9                   4.92
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df.tail()
# Out:
#       Patient_ID  Age  Gender Country_Region  Year  Genetic_Risk  \
# 49995  PT0049995   80    Male       Pakistan  2023           2.3
# 49996  PT0049996   40  Female            USA  2018           6.4
# 49997  PT0049997   74    Male       Pakistan  2015           6.2
# 49998  PT0049998   21    Male         Brazil  2018           4.0
# 49999  PT0049999   22    Male       Pakistan  2023           5.1
#
#        Air_Pollution  Alcohol_Use  Smoking  Obesity_Level Cancer_Type  \
# 49995            7.5          2.8      3.8            2.9    Leukemia
# 49996            3.5          2.9      9.0            9.8       Colon
# 49997            1.6          8.7      4.7            4.0      Breast
# 49998            6.5          7.6      8.6            8.1       Liver
# 49999            9.8          3.2      0.0            0.7       Liver
#
#       Cancer_Stage  Treatment_Cost_USD  Survival_Years  Target_Severity_Score
# ...

# %%
fig = plt.figure(figsize=(8, 4))
sns.countplot(x='Cancer_Type', data=df, palette='magma', hue='Gender')
plt.title('Distribution of Cancer Types')
plt.xlabel('Cancer Type')
plt.ylabel('Count')
plt.legend(loc='lower left')
plt.show()

# %%
fig = plt.figure(figsize=(6, 4))
sns.countplot(x='Country_Region', data=df, palette='magma')
plt.xticks(rotation=45)
plt.xlabel
plt.show()
# Out:
# C:\Users\aaron\AppData\Local\Temp\ipykernel_13144\1067086626.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Country_Region', data=df, palette='magma')

# %%
import plotly.express as px

# Create a DataFrame for age distribution
age_distribution = df.groupby(['Age', 'Cancer_Type']).size().reset_index(name='Count')

# Plot the interactive line chart
fig = px.line(age_distribution, x='Age', y='Count', color='Cancer_Type', 
              title='Age Distribution by Cancer Type', 
              labels={'Age': 'Age', 'Count': 'Count', 'Cancer_Type': 'Cancer Type'})
fig.update_layout(template='plotly_white')
fig.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Patient_ID             50000 non-null  object
#  1   Age                    50000 non-null  int64
#  2   Gender                 50000 non-null  object
#  3   Country_Region         50000 non-null  object
#  4   Year                   50000 non-null  int64
#  5   Genetic_Risk           50000 non-null  float64
#  6   Air_Pollution          50000 non-null  float64
#  7   Alcohol_Use            50000 non-null  float64
#  8   Smoking                50000 non-null  float64
#  9   Obesity_Level          50000 non-null  float64
#  10  Cancer_Type            50000 non-null  object
#  11  Cancer_Stage           50000 non-null  object
#  12  Treatment_Cost_USD     50000 non-null  float64
#  13  Survival_Years         50000 non-null  float64
# ...

# %%
float_columns = df.select_dtypes(include=['float']).columns.tolist()
print(float_columns)
# Out:
# ['Genetic_Risk', 'Air_Pollution', 'Alcohol_Use', 'Smoking', 'Obesity_Level', 'Treatment_Cost_USD', 'Survival_Years', 'Target_Severity_Score']

# %%
sns.heatmap(df[float_columns].corr(), annot=True, cmap='magma', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ### 🔍 Correlation Analysis: Understanding Risk Factors and Target Severity
#
# The heatmap above illustrates the correlation between various float-type features in the dataset and the `Target_Severity_Score`, which likely represents the severity of a patient's condition or disease state.
#
# #### 📌 Key Observations:
#
# - **Strong Positive Correlations with Target Severity**
#   - `Genetic_Risk` (0.48)
#   - `Smoking` (0.48)
#   - `Air_Pollution` (0.37)
#   - `Alcohol_Use` (0.36)
#   - `Obesity_Level` (0.25)
#
#   These findings suggest that lifestyle and environmental factors, along with genetic predisposition, play a significant role in increasing the severity of the condition. This aligns with known public health insights where behaviors like smoking and drinking, along with pollution exposure and obesity, elevate health risks.
#
# - **Notable Negative Correlation**
#   - `Treatment_Cost_USD` (-0.47): Surprisingly, higher treatment costs are associated with lower severity scores. This could indicate that early interventions (which cost more upfront) are effective at managing severity, or it might point to disparities in access to care for more severe cases.
#
# - **Survival Years Show Minimal Correlation**
#   - The `Survival_Years` feature shows negligible correlation with all other variables, including severity. This might indicate that survival is influenced by factors not captured here, or that it follows a more complex, non-linear relationship with the severity score.
#
# #### 🧠 Interpretation
#
# These correlations provide valuable insights into which factors are most closely tied to severity. Variables with higher absolute correlations to the target are strong candidates for further investigation or feature selection in predictive modeling tasks.
#
# In particular, `Genetic_Risk` and `Smoking` are likely the most critical variables for understanding and predicting severity, and merit deeper exploration in subsequent analyses.

# %%
sns.histplot(df['Target_Severity_Score'], kde=True, bins=30)
plt.title("Distribution of Target Severity Score")
plt.xlabel("Severity Score")
plt.ylabel("Count")
plt.show()

# %%
sns.scatterplot(data=df, x='Treatment_Cost_USD', y='Target_Severity_Score', hue='Cancer_Stage')
plt.title("Treatment Cost vs. Severity Score")
plt.xscale("log")  # If costs are skewed
plt.show()

# %%
df_grouped = df.groupby('Year')['Target_Severity_Score'].mean().reset_index()
sns.lineplot(data=df_grouped, x='Year', y='Target_Severity_Score')
plt.title("Average Severity Score Over Time")
plt.show()

# %%
sns.scatterplot(data=df, x='Target_Severity_Score', y='Survival_Years', hue='Cancer_Stage')
plt.title("Severity Score vs. Survival Years")
plt.show()
